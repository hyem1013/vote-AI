# %%
import random
from datetime import datetime
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from torch import nn, optim
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
import gc

# 1. 시드 및 장치 설정
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(0)
DEVICE = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# 2. 데이터 로드 및 전처리
drop_list = ['QaE', 'QbE', 'QcE', 'QdE', 'QeE', 'QfE', 'QgE', 'QhE', 'QiE', 'QjE',
             'QkE', 'QlE', 'QmE', 'QnE', 'QoE', 'QpE', 'QqE', 'QrE', 'QsE', 'QtE',
             'index', 'hand']
replace_dict = {'education': str, 'engnat': str, 'married': str, 'urban': str}

train_data = pd.read_csv('../../data/raw/train.csv')
test_data = pd.read_csv('../../data/raw/test_x.csv')
train_data = train_data.drop(train_data[train_data.familysize > 50].index)

train_y = train_data['voted']
train_x = train_data.drop(drop_list + ['voted'], axis=1)
test_x = test_data.drop(drop_list, axis=1)

train_x = train_x.astype(replace_dict)
test_x = test_x.astype(replace_dict)
train_x = pd.get_dummies(train_x)
test_x = pd.get_dummies(test_x)

# Baseline 특유의 타겟 처리 (1->1, 2->0)
train_y = 2 - train_y.to_numpy()
train_x = train_x.to_numpy().astype(float) 
test_x = test_x.to_numpy().astype(float)

# 텐서 변환 및 수동 스케일링
train_y_t = torch.tensor(train_y, dtype=torch.float32)
train_x_t = torch.tensor(train_x, dtype=torch.float32)
test_x_t = torch.tensor(test_x, dtype=torch.float32)

train_x_t[:, :20] = (train_x_t[:, :20] - 3.) / 2.
test_x_t[:, :20] = (test_x_t[:, :20] - 3.) / 2
train_x_t[:, 20] = (train_x_t[:, 20] - 5.) / 4.
test_x_t[:, 20] = (test_x_t[:, 20] - 5.) / 4.
train_x_t[:, 21:31] = (train_x_t[:, 21:31] - 3.5) / 3.5
test_x_t[:, 21:31] = (test_x_t[:, 21:31] - 3.5) / 3.5

test_len = len(test_x_t)
N_REPEAT = 15
N_SKFOLD = 5
N_EPOCH = 48
BATCH_SIZE = 72
LOADER_PARAM = {'batch_size': BATCH_SIZE, 'num_workers': 0, 'pin_memory': True} # M1 안정성 위해 0 권장

prediction = np.zeros((test_len, 1), dtype=np.float32)
total_val_aucs = []

# 3. 학습 루프
for repeat in range(N_REPEAT):
    skf = StratifiedKFold(n_splits=N_SKFOLD, random_state=repeat, shuffle=True)
    
    for skfold, (train_idx, valid_idx) in enumerate(skf.split(train_x, train_y)):
        train_loader = DataLoader(TensorDataset(train_x_t[train_idx], train_y_t[train_idx]),
                                  shuffle=True, drop_last=True, **LOADER_PARAM)
        valid_loader = DataLoader(TensorDataset(train_x_t[valid_idx], train_y_t[valid_idx]),
                                  shuffle=False, **LOADER_PARAM)
        
        # 모델: 노드 수 180 -> 256 상향
        model = nn.Sequential(
            nn.Dropout(0.05),
            nn.Linear(91, 256, bias=False), # 180에서 상향
            nn.LeakyReLU(0.05, inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, 32, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(32, 1)
        ).to(DEVICE)
        
        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([1.20665], device=DEVICE))
        optimizer = optim.AdamW(model.parameters(), lr=5e-3, weight_decay=7.8e-2)
        scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=N_EPOCH // 6, eta_min=4e-4)
        
        prediction_t = np.zeros((test_len, 1), dtype=np.float32)
        loss_t = 1.0
        best_auc_in_fold = 0

        for epoch in tqdm(range(N_EPOCH), desc='R{:02d} S{:02d}'.format(repeat + 1, skfold + 1)):
            model.train()
            for idx, (xx, yy) in enumerate(train_loader):
                optimizer.zero_grad()
                xx, yy = xx.to(DEVICE), yy.to(DEVICE)
                pred = model(xx).squeeze()
                loss = criterion(pred, yy)
                loss.backward()
                optimizer.step()
                scheduler.step(epoch + idx / len(train_loader))

            # 검증 및 AUC 확인
            model.eval()
            val_preds, val_targets = [], []
            running_loss, running_count = 0.0, 0
            with torch.no_grad():
                for xx, yy in valid_loader:
                    xx, yy = xx.to(DEVICE), yy.to(DEVICE)
                    logits = model(xx).squeeze()
                    loss = criterion(logits, yy)
                    running_loss += loss.item() * len(yy)
                    running_count += len(yy)
                    val_preds.extend(torch.sigmoid(logits).cpu().numpy())
                    val_targets.extend(yy.cpu().numpy())
            
            avg_val_loss = running_loss / running_count
            current_auc = roc_auc_score(val_targets, val_preds)

            # 성공 공식: Loss가 최소일 때의 테스트 예측값 저장
            if avg_val_loss < loss_t:
                loss_t = avg_val_loss
                best_auc_in_fold = current_auc
                # Test 예측 (Baseline 특유의 2. - sigmoid 유지)
                test_preds_fold = []
                test_loader = DataLoader(test_x_t, batch_size=BATCH_SIZE, shuffle=False)
                for xx in test_loader:
                    xx = xx.to(DEVICE)
                    # Baseline 방식의 결과값 산출
                    p = (2. - torch.sigmoid(model(xx).detach().to('cpu'))).numpy()
                    test_preds_fold.extend(p)
                prediction_t = np.array(test_preds_fold).reshape(-1, 1)

        total_val_aucs.append(best_auc_in_fold)
        prediction += prediction_t / (N_REPEAT * N_SKFOLD)
        
        # 메모리 관리
        del model; gc.collect(); torch.mps.empty_cache()

# 4. 최종 결과 출력
print("\n" + "="*40)
print(f"평균 Validation AUC: {np.mean(total_val_aucs):.5f}")
print(f"최고 AUC 기록: {np.max(total_val_aucs):.5f}")
print("="*40)

# 5. 제출 파일 저장
sub_df = pd.read_csv('../../data/raw/sample_submission.csv')
sub_df.iloc[:, 1:] = prediction
save_path = f'./submissions/exp09_{datetime.now().strftime("%m%d-%H%M")}_AUC_{np.mean(total_val_aucs):.4f}.csv'
sub_df.to_csv(save_path, index=False)
print(f"저장 완료: {save_path}")
# Out:
# R01 S01:   0%|          | 0/48 [00:00<?, ?it/s]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:   2%|▏         | 1/48 [00:02<01:47,  2.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:   4%|▍         | 2/48 [00:03<01:17,  1.68s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:   6%|▋         | 3/48 [00:04<01:10,  1.56s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:   8%|▊         | 4/48 [00:06<01:05,  1.49s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  10%|█         | 5/48 [00:07<01:02,  1.46s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  12%|█▎        | 6/48 [00:09<01:05,  1.56s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  15%|█▍        | 7/48 [00:10<01:01,  1.50s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  17%|█▋        | 8/48 [00:12<00:58,  1.45s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  19%|█▉        | 9/48 [00:13<00:55,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  21%|██        | 10/48 [00:14<00:51,  1.36s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  23%|██▎       | 11/48 [00:16<00:48,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  25%|██▌       | 12/48 [00:17<00:46,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  27%|██▋       | 13/48 [00:18<00:44,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  29%|██▉       | 14/48 [00:19<00:43,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  31%|███▏      | 15/48 [00:21<00:42,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  33%|███▎      | 16/48 [00:22<00:41,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  35%|███▌      | 17/48 [00:23<00:39,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  38%|███▊      | 18/48 [00:24<00:38,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  40%|███▉      | 19/48 [00:26<00:36,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  42%|████▏     | 20/48 [00:27<00:35,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  44%|████▍     | 21/48 [00:28<00:33,  1.25s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  46%|████▌     | 22/48 [00:29<00:32,  1.25s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  48%|████▊     | 23/48 [00:31<00:32,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  50%|█████     | 24/48 [00:32<00:31,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  52%|█████▏    | 25/48 [00:33<00:30,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  54%|█████▍    | 26/48 [00:35<00:28,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  56%|█████▋    | 27/48 [00:36<00:26,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  58%|█████▊    | 28/48 [00:37<00:25,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  60%|██████    | 29/48 [00:38<00:23,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  62%|██████▎   | 30/48 [00:40<00:22,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  65%|██████▍   | 31/48 [00:41<00:21,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  67%|██████▋   | 32/48 [00:42<00:20,  1.25s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  69%|██████▉   | 33/48 [00:43<00:18,  1.23s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  71%|███████   | 34/48 [00:45<00:17,  1.24s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  73%|███████▎  | 35/48 [00:46<00:16,  1.24s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  75%|███████▌  | 36/48 [00:47<00:14,  1.24s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  77%|███████▋  | 37/48 [00:48<00:13,  1.23s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  79%|███████▉  | 38/48 [00:50<00:12,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  81%|████████▏ | 39/48 [00:51<00:11,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  83%|████████▎ | 40/48 [00:52<00:09,  1.23s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  85%|████████▌ | 41/48 [00:53<00:08,  1.23s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  88%|████████▊ | 42/48 [00:54<00:07,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  90%|████████▉ | 43/48 [00:56<00:06,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  92%|█████████▏| 44/48 [00:57<00:04,  1.21s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  94%|█████████▍| 45/48 [00:58<00:03,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  96%|█████████▌| 46/48 [00:59<00:02,  1.23s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01:  98%|█████████▊| 47/48 [01:01<00:01,  1.22s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S01: 100%|██████████| 48/48 [01:02<00:00,  1.30s/it]
# R01 S02:   0%|          | 0/48 [00:00<?, ?it/s]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:   2%|▏         | 1/48 [00:01<01:02,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:   4%|▍         | 2/48 [00:02<01:01,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:   6%|▋         | 3/48 [00:04<01:00,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:   8%|▊         | 4/48 [00:05<00:58,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  10%|█         | 5/48 [00:06<00:57,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  12%|█▎        | 6/48 [00:08<00:57,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  15%|█▍        | 7/48 [00:09<00:56,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  17%|█▋        | 8/48 [00:10<00:56,  1.40s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  19%|█▉        | 9/48 [00:12<00:54,  1.39s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  21%|██        | 10/48 [00:13<00:52,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  23%|██▎       | 11/48 [00:14<00:49,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  25%|██▌       | 12/48 [00:16<00:48,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  27%|██▋       | 13/48 [00:17<00:46,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  29%|██▉       | 14/48 [00:18<00:45,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  31%|███▏      | 15/48 [00:20<00:43,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  33%|███▎      | 16/48 [00:21<00:43,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  35%|███▌      | 17/48 [00:22<00:41,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  38%|███▊      | 18/48 [00:24<00:39,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  40%|███▉      | 19/48 [00:25<00:38,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  42%|████▏     | 20/48 [00:26<00:36,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  44%|████▍     | 21/48 [00:28<00:35,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  46%|████▌     | 22/48 [00:29<00:33,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  48%|████▊     | 23/48 [00:30<00:32,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  50%|█████     | 24/48 [00:32<00:31,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  52%|█████▏    | 25/48 [00:33<00:29,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  54%|█████▍    | 26/48 [00:34<00:28,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  56%|█████▋    | 27/48 [00:35<00:27,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  58%|█████▊    | 28/48 [00:37<00:25,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  60%|██████    | 29/48 [00:38<00:24,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  62%|██████▎   | 30/48 [00:39<00:23,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  65%|██████▍   | 31/48 [00:41<00:22,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  67%|██████▋   | 32/48 [00:42<00:21,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  69%|██████▉   | 33/48 [00:43<00:20,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  71%|███████   | 34/48 [00:45<00:19,  1.39s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  73%|███████▎  | 35/48 [00:46<00:17,  1.36s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  75%|███████▌  | 36/48 [00:47<00:16,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  77%|███████▋  | 37/48 [00:49<00:14,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  79%|███████▉  | 38/48 [00:50<00:13,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  81%|████████▏ | 39/48 [00:51<00:12,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  83%|████████▎ | 40/48 [00:53<00:10,  1.37s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  85%|████████▌ | 41/48 [00:54<00:09,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  88%|████████▊ | 42/48 [00:55<00:07,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  90%|████████▉ | 43/48 [00:57<00:06,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  92%|█████████▏| 44/48 [00:58<00:05,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  94%|█████████▍| 45/48 [00:59<00:03,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  96%|█████████▌| 46/48 [01:01<00:02,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02:  98%|█████████▊| 47/48 [01:02<00:01,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S02: 100%|██████████| 48/48 [01:03<00:00,  1.33s/it]
# R01 S03:   0%|          | 0/48 [00:00<?, ?it/s]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:   2%|▏         | 1/48 [00:01<01:06,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:   4%|▍         | 2/48 [00:02<01:00,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:   6%|▋         | 3/48 [00:04<01:01,  1.37s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:   8%|▊         | 4/48 [00:05<01:00,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  10%|█         | 5/48 [00:06<01:00,  1.41s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  12%|█▎        | 6/48 [00:08<00:58,  1.39s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  15%|█▍        | 7/48 [00:09<00:56,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  17%|█▋        | 8/48 [00:10<00:53,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  19%|█▉        | 9/48 [00:12<00:52,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  21%|██        | 10/48 [00:13<00:51,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  23%|██▎       | 11/48 [00:14<00:49,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  25%|██▌       | 12/48 [00:16<00:48,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  27%|██▋       | 13/48 [00:17<00:46,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  29%|██▉       | 14/48 [00:18<00:44,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  31%|███▏      | 15/48 [00:20<00:43,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  33%|███▎      | 16/48 [00:21<00:42,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  35%|███▌      | 17/48 [00:22<00:41,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  38%|███▊      | 18/48 [00:24<00:40,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  40%|███▉      | 19/48 [00:25<00:39,  1.36s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  42%|████▏     | 20/48 [00:26<00:37,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  44%|████▍     | 21/48 [00:28<00:35,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  46%|████▌     | 22/48 [00:29<00:34,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  48%|████▊     | 23/48 [00:30<00:32,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  50%|█████     | 24/48 [00:32<00:31,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  52%|█████▏    | 25/48 [00:33<00:29,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  54%|█████▍    | 26/48 [00:34<00:27,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  56%|█████▋    | 27/48 [00:35<00:26,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  58%|█████▊    | 28/48 [00:37<00:25,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  60%|██████    | 29/48 [00:38<00:24,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  62%|██████▎   | 30/48 [00:39<00:23,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  65%|██████▍   | 31/48 [00:40<00:21,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  67%|██████▋   | 32/48 [00:42<00:20,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  69%|██████▉   | 33/48 [00:43<00:19,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  71%|███████   | 34/48 [00:44<00:18,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  73%|███████▎  | 35/48 [00:46<00:16,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  75%|███████▌  | 36/48 [00:47<00:15,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  77%|███████▋  | 37/48 [00:48<00:14,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  79%|███████▉  | 38/48 [00:50<00:13,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  81%|████████▏ | 39/48 [00:51<00:12,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  83%|████████▎ | 40/48 [00:52<00:10,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  85%|████████▌ | 41/48 [00:54<00:09,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  88%|████████▊ | 42/48 [00:55<00:07,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  90%|████████▉ | 43/48 [00:56<00:06,  1.27s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  92%|█████████▏| 44/48 [00:57<00:05,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  94%|█████████▍| 45/48 [00:59<00:03,  1.26s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  96%|█████████▌| 46/48 [01:00<00:02,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03:  98%|█████████▊| 47/48 [01:01<00:01,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S03: 100%|██████████| 48/48 [01:03<00:00,  1.31s/it]
# R01 S04:   0%|          | 0/48 [00:00<?, ?it/s]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:   2%|▏         | 1/48 [00:01<01:07,  1.43s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:   4%|▍         | 2/48 [00:02<01:05,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:   6%|▋         | 3/48 [00:04<01:03,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:   8%|▊         | 4/48 [00:05<00:59,  1.36s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  10%|█         | 5/48 [00:06<00:59,  1.39s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  12%|█▎        | 6/48 [00:08<00:58,  1.40s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  15%|█▍        | 7/48 [00:09<00:55,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  17%|█▋        | 8/48 [00:10<00:52,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  19%|█▉        | 9/48 [00:12<00:51,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  21%|██        | 10/48 [00:13<00:49,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  23%|██▎       | 11/48 [00:14<00:47,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  25%|██▌       | 12/48 [00:15<00:46,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  27%|██▋       | 13/48 [00:17<00:44,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  29%|██▉       | 14/48 [00:18<00:43,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  31%|███▏      | 15/48 [00:19<00:43,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  33%|███▎      | 16/48 [00:21<00:42,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  35%|███▌      | 17/48 [00:22<00:40,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  38%|███▊      | 18/48 [00:23<00:39,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  40%|███▉      | 19/48 [00:25<00:38,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R01 S04:  42%|████▏     | 20/48 [00:26<00:36,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# R15 S04:  88%|████████▊ | 42/48 [00:55<00:07,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04:  90%|████████▉ | 43/48 [00:56<00:06,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04:  92%|█████████▏| 44/48 [00:58<00:05,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04:  94%|█████████▍| 45/48 [00:59<00:03,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04:  96%|█████████▌| 46/48 [01:00<00:02,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04:  98%|█████████▊| 47/48 [01:01<00:01,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S04: 100%|██████████| 48/48 [01:03<00:00,  1.32s/it]
# R15 S05:   0%|          | 0/48 [00:00<?, ?it/s]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:   2%|▏         | 1/48 [00:01<01:08,  1.46s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:   4%|▍         | 2/48 [00:02<01:06,  1.45s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:   6%|▋         | 3/48 [00:04<01:03,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:   8%|▊         | 4/48 [00:05<01:02,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  10%|█         | 5/48 [00:07<01:01,  1.43s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  12%|█▎        | 6/48 [00:08<00:59,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  15%|█▍        | 7/48 [00:10<00:58,  1.43s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  17%|█▋        | 8/48 [00:11<00:56,  1.42s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  19%|█▉        | 9/48 [00:12<00:54,  1.39s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  21%|██        | 10/48 [00:13<00:51,  1.36s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  23%|██▎       | 11/48 [00:15<00:49,  1.34s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  25%|██▌       | 12/48 [00:16<00:47,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  27%|██▋       | 13/48 [00:17<00:46,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  29%|██▉       | 14/48 [00:19<00:45,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  31%|███▏      | 15/48 [00:20<00:45,  1.38s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  33%|███▎      | 16/48 [00:22<00:43,  1.35s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  35%|███▌      | 17/48 [00:23<00:41,  1.33s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  38%|███▊      | 18/48 [00:24<00:39,  1.32s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  40%|███▉      | 19/48 [00:25<00:37,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  42%|████▏     | 20/48 [00:27<00:36,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  44%|████▍     | 21/48 [00:28<00:35,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  46%|████▌     | 22/48 [00:29<00:33,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  48%|████▊     | 23/48 [00:31<00:32,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  50%|█████     | 24/48 [00:32<00:31,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  52%|█████▏    | 25/48 [00:33<00:29,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  54%|█████▍    | 26/48 [00:34<00:28,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  56%|█████▋    | 27/48 [00:36<00:27,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  58%|█████▊    | 28/48 [00:37<00:25,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  60%|██████    | 29/48 [00:38<00:24,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  62%|██████▎   | 30/48 [00:40<00:23,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  65%|██████▍   | 31/48 [00:41<00:22,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  67%|██████▋   | 32/48 [00:42<00:20,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  69%|██████▉   | 33/48 [00:43<00:19,  1.28s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  71%|███████   | 34/48 [00:45<00:18,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  73%|███████▎  | 35/48 [00:46<00:16,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  75%|███████▌  | 36/48 [00:47<00:15,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  77%|███████▋  | 37/48 [00:49<00:14,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  79%|███████▉  | 38/48 [00:50<00:13,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  81%|████████▏ | 39/48 [00:51<00:11,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  83%|████████▎ | 40/48 [00:53<00:10,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  85%|████████▌ | 41/48 [00:54<00:09,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  88%|████████▊ | 42/48 [00:55<00:07,  1.30s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  90%|████████▉ | 43/48 [00:56<00:06,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  92%|█████████▏| 44/48 [00:58<00:05,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  94%|█████████▍| 45/48 [00:59<00:03,  1.31s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  96%|█████████▌| 46/48 [01:00<00:02,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05:  98%|█████████▊| 47/48 [01:02<00:01,  1.29s/it]/opt/anaconda3/envs/voteai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# R15 S05: 100%|██████████| 48/48 [01:03<00:00,  1.32s/it]
# ========================================
# 평균 Validation AUC: 0.77233
# 최고 AUC 기록: 0.77892
# ========================================
# 저장 완료: ./submissions/exp09_0131-2057_AUC_0.7723.csv
