# %%
import torch
import numpy as np
import pandas as pd
import optuna

print(f"PyTorch 버전: {torch.__version__}")
print(f"Pandas 버전: {pd.__version__}")
print(f"Optuna 버전: {optuna.__version__}")
print(f"M1 GPU 가속 가능 여부: {torch.backends.mps.is_available()}")

print(f"NumPy 버전: {np.__version__}") # 1.26.x 안정적 / pip install "numpy<2"
print(f"PyTorch 버전: {torch.__version__}")

# PyTorch/Scikit-learn가 Numpy 2.x대랑 충돌이 생김
test_tensor = torch.randn(3, 3).numpy()
print("텐서가 넘파이 배열로 정상 변환되었습니다.")
# Out:
# PyTorch 버전: 2.1.0
# Pandas 버전: 2.1.1
# Optuna 버전: 3.3.0
# M1 GPU 가속 가능 여부: True
# NumPy 버전: 1.26.0
# PyTorch 버전: 2.1.0
# 텐서가 넘파이 배열로 정상 변환되었습니다.
